# %%
# Import Dependencies
from pymongo import MongoClient
from config import cloudM, cloudMpassword
import pandas as pd
import numpy as np
import datetime as dt
import csv
import re

# %%
#load data
df = pd.read_csv("final_pass.csv")
df.head()
# Out:
#     Country Geography: Geographic coordinates Latitude Longitude  \
# 0   Germany                   51 00 N, 9 00 E  51 00 N    9 00 E
# 1     Italy                  42 50 N, 12 50 E  42 50 N   12 50 E
# 2    Canada                  60 00 N, 95 00 W  60 00 N   95 00 W
# 3   Ireland                   53 00 N, 8 00 W  53 00 N    8 00 W
# 4  Cameroon                   6 00 N, 12 00 E   6 00 N   12 00 E
#
#   Geography: Map references Geography: Area - total  \
# 0                    Europe           357,022 sq km
# 1                    Europe           301,340 sq km
# 2             North America         9,984,670 sq km
# 3                    Europe            70,273 sq km
# 4                    Africa           475,440 sq km
#
#    2020 Real GDP (purchasing power parity, in billions)  \
# 0                                            4238.80
# 1                                            2322.14
# 2                                            1742.79
# 3                                             447.97
# 4                                              94.94
#
#   2019 Real GDP (purchasing power parity, in billons)  \
# 0                                            4457.05
# 1                                            2548.19
# 2                                            1842.33
# 3                                           $433.17
# 4                                            $94.25
#
#    2018 Real GDP (purchasing power parity, in billions)  \
# 0                                            4432.43
# 1                                            2540.89
# 2                                            1808.66
# 3                                             410.33
# 4                                              90.87
#
#   GDP Growth Rate Est 1 (in %)  ...  \
# 0                        0.59%  ...
# 1                        0.34%  ...
# 2                        1.66%  ...
# 3                        5.86%  ...
# 4                        3.50%  ...
#
#    Total Fertility Rate (children born/woman (2022 est.),  \
# 0                                               1.57
# 1                                               1.22
# 2                                               1.57
# 3                                               1.92
# 4                                               4.55
#
#   Adult Obesity Rate in % (Est 2016)  Tobacco Use in % (Est 2020)  \
# 0                             22.30%                          22%
# 1                             19.90%                       23.10%
# 2                             29.40%                          13%
# 3                             25.30%                       20.80%
# 4                             11.40%                        7.30%
#
#    Internet Users (Est 2020)  Internet Users in % of Population (Est 2020)  \
# 0                 74,844,784                                           90%
# 1                 41,614,669                                           70%
# 2                 36,896,088                                           97%
# 3                  4,586,820                                           92%
# 4                 10,087,428                                           38%
#
#   2021 Military Expenditures (as % of GDP)  \
# 0                                    1.50%
# 1                                    1.50%
# 2                                    1.40%
# 3                                    0.30%
# 4                                       1%
#
#   2020 Military Expenditures (as % of GDP)  \
# 0                                    1.50%
# 1                                    1.60%
# 2                                    1.40%
# 3                                    0.30%
# 4                                       1%
#
#   Approx Military Service Age and Obligation  \
# 0                                     17-23
# 1                                     18-25
# 2                                         17
# 3                                     18-25
# 4                                     18-23
#
#                        Terrorism: Terrorist group(s)  \
# 0  Islamic Revolutionary Guard Corps/Qods Force; ...
# 1          Islamic State of Iraq and ash-Sham (ISIS)
# 2  Islamic State of Iraq and ash-Sham (ISIS); Hiz...
# 3  Continuity Irish Republican Army; New Irish Re...
# 4  Boko Haram; Islamic State of Iraq and ash-Sham...
#
#               Military and Security: Military - note
# 0  the Federal Republic of Germany joined NATO in...
# 1  Italy is a member of NATO and was one of the o...
# 2  Canada is a member of NATO and was one of the ...
# 3  the Irish Defense Forces trace their origins b...
# 4  as of 2022, the FAC was largely focused on the...
#
# [5 rows x 79 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 79 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Country                                                  48 non-null     object
#  1   Geography: Geographic coordinates                        48 non-null     object
#  2   Latitude                                                 48 non-null     object
#  3   Longitude                                                48 non-null     object
#  4   Geography: Map references                                48 non-null     object
#  5   Geography: Area - total                                  48 non-null     object
#  6   2020 Real GDP (purchasing power parity, in billions)     48 non-null     float64
#  7   2019 Real GDP (purchasing power parity, in billons)      48 non-null     object
#  8   2018 Real GDP (purchasing power parity, in billions)     48 non-null     float64
#  9   GDP Growth Rate Est 1 (in %)                             48 non-null     object
#  10  GDP Growth Rate Est 1 - Year                             48 non-null     int64
#  11  GDP Growth Rate Est 2 (in %)                             48 non-null     object
#  12  GDP Growth Rate Est 2 - Year                             48 non-null     int64
#  13  GDP Growth Rate Est 3 (in %)                             48 non-null     object
#  14  GDP Growth Rate Est 3 - Year                             48 non-null     int64
#  15  2020 GDP per Capita (in $)                               48 non-null     object
#  16  2019 GDP per Capita (in $)                               48 non-null     object
#  17  2018 GDP per Capita (in $)                               48 non-null     object
#  18  Econ: Current Acct Bal Est 1 (in billions)               48 non-null     float64
#  19  Econ: Current Acct Bal Est 1 - Years                     48 non-null     int64
#  20  Econ: Current Acct Bal Est 2 (in billions)               48 non-null     float64
#  21  Econ: Current Acct Bal Est 2 - Years                     48 non-null     int64
#  22  Exports (Est 2019 -2020)                                 48 non-null     object
#  23  Exports (Est 2018 -2019)                                 47 non-null     object
#  24  Top Export Partner- Country                              48 non-null     object
#  25  Top Export Partner- %                                    48 non-null     object
#  26  Foreign Exchange & Gold - Est 2017 (in billions)         48 non-null     object
#  27  Total Population Electrification by % (Est 2019 - 2020)  48 non-null     object
#  28  Moody's rating                                           48 non-null     object
#  29  Moody's Rating - Year                                    48 non-null     int64
#  30   Standard & Poors Rating                                 48 non-null     object
#  31   Standard & Poors Rating - Year                          48 non-null     int64
#  32  Fitch Rating                                             48 non-null     object
#  33  Fitch Rating - Year                                      48 non-null     int64
#  34  Unemployment Rate in %                                   48 non-null     object
#  35  Unemployment Rate - Year of Est.                         48 non-null     int64
#  36  Population Below Poverty Line in %                       48 non-null     object
#  37  Population Below Poverty Line - Year of Est              48 non-null     int64
#  38   Household Income or Consumption by %                    48 non-null     object
#  39   Household Income or Consumption by - year Est           48 non-null     int64
#  40  People and Society: Nationality - Noun                   48 non-null     object
#  41   Population Growth Rate (Est 2022)                       48 non-null     object
#  42  Population Growth Rate in % (Est 2022)                   48 non-null     object
#  43  Percent of Population 14 yrs and under,                  48 non-null     object
#  44  Males 14 yrs and Under                                   48 non-null     object
#  45  Females 14 yrs and Under                                 48 non-null     object
#  46  Percent of People 15-24 yrs                              48 non-null     object
#  47  Males Between 15-24                                      48 non-null     object
#  48  Females Between 15-24 Year                               48 non-null     object
#  49   Percent of People 25-54 yrs                             48 non-null     object
#  50   Males Between 25-54 yrs                                 48 non-null     object
#  51   Females Between 25-54 yrs                               48 non-null     object
#  52  Percent of People 55-64                                  48 non-null     object
#  53  Males Between 55-64 yrs                                  48 non-null     object
#  54  Females Between 55-64 yrs                                48 non-null     object
#  55   Median Age (in years),                                  48 non-null     float64
#  56   Male Median Age (in years)                              48 non-null     float64
#  57   Female Median Age (in years)                            48 non-null     float64
#  58  Birth rate (births/1,000 population, Est 2022)           48 non-null     float64
#  59  Death rate (death/1,000 population, 2022 est)            48 non-null     float64
#  60  Migration rate (migrants/1,000 population, 2022 est)     48 non-null     float64
#  61  Urbanization -% of Population                            48 non-null     object
#  62  Gender Ratio - at Birth( male(s)/female)                 48 non-null     float64
#  63  Gender Ratio - 65 years and over (male(s)/female)        48 non-null     float64
#  64   Total Population Gender Ratio (male(s)/female)          48 non-null     float64
#  65  Infant Mortality Rate (deaths/1,000 live births)         48 non-null     float64
#  66  Life Expectancy at Birth (in years)                      48 non-null     float64
#  67   Male Life expectancy at birth (in years)                48 non-null     float64
#  68  Female Life expectancy at birth (in years),              48 non-null     float64
#  69  Total Fertility Rate (children born/woman (2022 est.),   48 non-null     float64
#  70  Adult Obesity Rate in % (Est 2016)                       48 non-null     object
#  71  Tobacco Use in % (Est 2020)                              48 non-null     object
#  72   Internet Users (Est 2020)                               48 non-null     object
#  73  Internet Users in % of Population (Est 2020)             48 non-null     object
#  74  2021 Military Expenditures (as % of GDP)                 48 non-null     object
#  75  2020 Military Expenditures (as % of GDP)                 48 non-null     object
#  76  Approx Military Service Age and Obligation               41 non-null     object
#  77  Terrorism: Terrorist group(s)                            48 non-null     object
#  78  Military and Security: Military - note                   48 non-null     object
# dtypes: float64(18), int64(11), object(50)
# memory usage: 29.8+ KB

# %% [markdown]
# # upload to Mongo

# %%
# connect notebook to cloud
from config import cloudM, cloudMpassword
cloudstr  = f"mongodb+srv://{cloudM}:{cloudMpassword}@finalproject.1pamme7.mongodb.net/test"

# %%
cloudclient = MongoClient(cloudstr)
#upload to cloud
db = cloudclient['final_project']
colmanager = db["clean_cia"]
colmanager.insert_many(df.to_dict('records'))
